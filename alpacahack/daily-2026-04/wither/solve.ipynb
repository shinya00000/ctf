# %%
# !pip install pwntools -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 61.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.0/161.0 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 8.1 MB/s eta 0:00:00

# %%
import os
os.environ['PWNLIB_NOTERM'] = '1'

# %%
from pwn import *

io = remote("34.170.146.252", 29127)

recovered_flag = None

# 100回ループ
for i in range(100):
    io.sendline(b"")
    io.recvuntil(b"Encrypted flag: ")

    hex_str = io.recvline().strip().decode()
    cipher = bytes.fromhex(hex_str)

    if recovered_flag is None:
        recovered_flag = bytearray(cipher)
    else:
        for j in range(len(cipher)):
            recovered_flag[j] |= cipher[j]

    #current_text = recovered_flag.decode(errors="backslashreplace")
    #print(f"[{i+1:03d}] Current: {current_text}")

print(f"\n[+] Final Recovered Flag:")
print(recovered_flag.decode('utf-8'))

io.close()
# Out:
# [x] Opening connection to 34.170.146.252 on port 29127
# INFO:pwnlib.tubes.remote.remote.139716193060528:Opening connection to 34.170.146.252 on port 29127
# [x] Opening connection to 34.170.146.252 on port 29127: Trying 34.170.146.252
# INFO:pwnlib.tubes.remote.remote.139716193060528:Opening connection to 34.170.146.252 on port 29127: Trying 34.170.146.252
# [+] Opening connection to 34.170.146.252 on port 29127: Done
# INFO:pwnlib.tubes.remote.remote.139716193060528:Opening connection to 34.170.146.252 on port 29127: Done
# [+] Final Recovered Flag:
# Alpaca{Bebe_skyscraper,_night_draper,_I_inhaling_vapor,_huh}
# [*] Closed connection to 34.170.146.252 port 29127
# INFO:pwnlib.tubes.remote.remote.139716193060528:Closed connection to 34.170.146.252 port 29127
